# %% [markdown]
# <a href="https://colab.research.google.com/github/guihensn/investment-studies/blob/main/01_Python_para_Investimentos_com_Google_Colab_Obtendo_cota%C3%A7%C3%B5es_do_Yahoo_Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Ricos pelo Acaso

# %% [markdown]
# Link do vídeo: https://youtu.be/7GGrt3-rRH8

# %% [markdown]
# # Bibliotecas

# %% [markdown]
# >Instalando o YFinance

# %%
# !pip install yfinance --upgrade --no-cache-dir

# %% [markdown]
# >Importando as Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %% [markdown]
# >Importando o YFinance e sobrescrevendo os métodos do `pandas_datareader`

# %%
import yfinance as yf
ibov = yf.download('^BVSP', start="2024-01-01", end="2024-03-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Obtendo os dados do mercado

# %% [markdown]
# >Baixando as cotações do Yahoo Finance para o Índice Bovespa

# %%
ibov = yf.download('^BVSP', start="2000-01-01", end="2024-03-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# >Exibindo as cotações mais antigas

# %%
ibov.head()
# Out:
# Price         Close     High      Low     Open Volume
# Ticker        ^BVSP    ^BVSP    ^BVSP    ^BVSP  ^BVSP
# Date
# 2000-01-03  16930.0  17408.0  16719.0  17098.0      0
# 2000-01-04  15851.0  16908.0  15851.0  16908.0      0
# 2000-01-05  16245.0  16302.0  15350.0  15871.0      0
# 2000-01-06  16107.0  16499.0  15977.0  16237.0      0
# 2000-01-07  16309.0  16449.0  16125.0  16125.0      0

# %% [markdown]
# >Exibindo as cotações mais recentes

# %%
ibov.tail()
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP     ^BVSP
# Date
# 2024-02-23  129419.0  130624.0  129077.0  130240.0   9230300
# 2024-02-26  129609.0  129978.0  129077.0  129417.0   7436900
# 2024-02-27  131689.0  131696.0  129613.0  129613.0  10049000
# 2024-02-28  130155.0  131685.0  129771.0  131685.0   9045600
# 2024-02-29  129020.0  130155.0  128669.0  130155.0  12003100

# %% [markdown]
# >Plotando o gráfico com o preços de fechamento do Índice Bovespa

# %%
ibov["Close"].plot(figsize=(22,8));
